# %%
# Importing Libraries",
import selenium
import pandas as pd
import numpy as np
import time
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import warnings
from selenium.webdriver.common.keys import Keys
warnings.filterwarnings('ignore')
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
#connecting to the webdriver
driver= webdriver.Chrome(r"C:\Users\LENOVO\Downloads\chromedriver_win32 (2)/chromedriver")

# %%
#opening the cars24 website
url = 'https://bit.ly/3HbOtY7'
driver.get(url)

# %%
driver.find_element_by_xpath("//div[@class='float-right TBxAN']").click()

# %%
#Creating empty lists
brand=[]
year=[]
fuel=[]
transmission=[]
km=[]
price=[]
prod_URL=[]

# %%
#Getting the URL of the cars
for i in range(0,500):
    url=driver.find_elements_by_xpath("//div[@class='col-4']/a")
    for i in url:
        prod_URL.append(i.get_attribute('href'))
    try:
        next_btn = driver.find_element_by_xpath("//button[@class='btn _3BmFU AgO6q']").click()
    except NoSuchElementException:
        pass

# %%
prod_URL
# Out:
# ['https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2012-cars-Faridabad-1006597628/',
#  'https://www.cars24.com/buy-used-Maruti-A-Star-2009-cars-Gurgaon-1122619346/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2012-cars-New-Delhi-1017631849/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2012-cars-Gurgaon-1124310622/',
#  'https://www.cars24.com/buy-used-Maruti-Zen-Estilo-2009-cars-Noida-1010676821/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2012-cars-New-Delhi-1016464922/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2013-cars-New-Delhi-1001699649/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2013-cars-Noida-1125443125/',
#  'https://www.cars24.com/buy-used-Maruti-S-Cross-2016-cars-New-Delhi-1002987041/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2014-cars-Faridabad-1008852945/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2015-cars-Noida-1006609108/',
# ...

# %%
for i in prod_URL:
    driver.get(i) 
    
#Extracting car name
    try:
        brand.append(driver.find_element_by_xpath("//h2[@class='_3FpCg']").text)
    except NoSuchElementException as e:
        brand.append("-")
        
#Extracting the transmission
    try:
        transmission.append(driver.find_element_by_xpath("//p[@class='cvakB']/span").text)  
    except NoSuchElementException as e:
        transmission.append("-")
        
#Extracting the fuel consumed
    try:
        fuel.append(driver.find_element_by_xpath("//ul[@class='bVR0c']/li[3]").text)
    except NoSuchElementException as e:
        fuel.append("-")
        
#Extracting km driven
    try:
        km.append(driver.find_element_by_xpath("//ul[@class='bVR0c']/li[1]").text)
    except NoSuchElementException as e:
        km.append("-") 
        

        #Extracting the price details
    try:
        price.append(driver.find_element_by_xpath("//div[@class='_7udZZ']").text.replace('₹',''))
    except NoSuchElementException as e:
        price.append("-")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-13-5efff5924350> in <module>
#       1 for i in prod_URL:
# ----> 2     driver.get(i)
#       3
#       4 #Extracting car name
#       5     try:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     434         Loads a web page in the current browser session.
#     435         """
# --> 436         self.execute(Command.GET, {'url': url})
#     437
#     438     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
# ...

# %%
#Creating a dataframe and checking the data extracted
cars24 = pd.DataFrame({'name':brand,'selling_price':price,'km_driven':km,'fuel':fuel,'transmission':transmission})

# %%
cars24
# Out:
#                         name selling_price    km_driven    fuel transmission
# 0    2014 Maruti Swift Dzire      3,54,799    76,013 km  Diesel       Manual
# 1             2015 Tata Nano      1,87,999    39,703 km  Petrol       Manual
# 2          2012 Maruti Swift      2,60,099  1,20,326 km  Diesel       Manual
# 3          2012 Maruti Swift      2,82,099    68,206 km  Diesel       Manual
# 4             2015 Tata Nano      1,85,999    43,402 km  Petrol       Manual
# ..                       ...           ...          ...     ...          ...
# 487  2014 Maruti Swift Dzire      3,54,799    76,013 km  Diesel       Manual
# 488      2015 Maruti S Cross      5,39,999    94,544 km  Diesel       Manual
# 489  2012 Maruti Swift Dzire      3,05,899  1,18,117 km  Diesel       Manual
# 490        2014 Maruti Swift      4,07,199    54,884 km  Diesel       Manual
# 491  2015 Maruti Swift Dzire      5,09,299    13,258 km  Diesel       Manual
#
# [492 rows x 5 columns]

# %%
#Saving in a csv file
cars24.to_csv('cars24data.csv')

# %%
pd.read_csv('cars24data.csv')
# Out:
#      Unnamed: 0                     name selling_price    km_driven    fuel  \
# 0             0  2014 Maruti Swift Dzire      3,54,799    76,013 km  Diesel
# 1             1           2015 Tata Nano      1,87,999    39,703 km  Petrol
# 2             2        2012 Maruti Swift      2,60,099  1,20,326 km  Diesel
# 3             3        2012 Maruti Swift      2,82,099    68,206 km  Diesel
# 4             4           2015 Tata Nano      1,85,999    43,402 km  Petrol
# ..          ...                      ...           ...          ...     ...
# 487         487  2014 Maruti Swift Dzire      3,54,799    76,013 km  Diesel
# 488         488      2015 Maruti S Cross      5,39,999    94,544 km  Diesel
# 489         489  2012 Maruti Swift Dzire      3,05,899  1,18,117 km  Diesel
# 490         490        2014 Maruti Swift      4,07,199    54,884 km  Diesel
# 491         491  2015 Maruti Swift Dzire      5,09,299    13,258 km  Diesel
#
#     transmission
# 0         Manual
# 1         Manual
# ...
